# %%
import subprocess
import sys
import os
import datetime


# Path to the folder containing your scripts
#BASE_DIR = "../../Module/pythonFiles"#"Project/Project/IntermediaryPythonFiles"
BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), "..", "Module"))


# Constants used:
current_date = datetime.datetime.now().strftime("%Y_%B_%d")
experiment_name = current_date


# Scripts to run in order
scripts = [
    #"Fetch_Data.py",
    "0.1_read_data.py",
    "0.2_data_preprocessing"
    "1.0_Train.py",
    "1.1_TrainXGBoost.py",
    "1.2_TrainSKLearnLog.py",   
    "2.0_SelectBestModelAndRegister.py",
    "3.0_Deploy.py"
]

for script in scripts:
    full_path = os.path.join(BASE_DIR, script)
    print(f"\n=== Running {script} ===\n")

    result = subprocess.run(
        [sys.executable, full_path, "--run_name", experiment_name]
    )

    if result.returncode != 0:
        print(f"{script} failed with exit code {result.returncode}")
        break

    print(f"✔ Finished {script}")
# Out:
# === Running 0.1_read_data.py ===
# 2025-12-07 23:02:49.873 | INFO     | config:<module>:11 - PROJ_ROOT path is: /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project
# Traceback (most recent call last):
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project/Module/0.1_read_data.py", line 19, in <module>
#     data = pd.read_csv(RAW_DATA_FILE)
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py", line 1026, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py", line 620, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py", line 1620, in __init__
#     self._engine = self._make_engine(f, self.engine)
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py", line 1880, in _make_engine
#     self.handles = get_handle(
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/pandas/io/common.py", line 873, in get_handle
#     handle = open(
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project/data/raw/raw_data.csv'
# Loading training data
# 0.1_read_data.py failed with exit code 1
