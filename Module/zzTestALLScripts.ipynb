# %%
import subprocess
import sys
import os
import datetime


# Path to the folder containing your scripts
#BASE_DIR = "../../Module/pythonFiles"#"Project/Project/IntermediaryPythonFiles"
BASE_DIR = os.path.abspath(os.path.join(os.getcwd()))


# Constants used:
current_date = datetime.datetime.now().strftime("%Y_%B_%d")
experiment_name = current_date


# Scripts to run in order
scripts = [
    #"0.0_Fetch_Data.py",
    "0.1_read_data.py",
    "0.2_data_preprocessing.py",
    "1.0_Train.py",
    "1.1_TrainXGBoost.py",
    "1.2_TrainSKLearnLog.py",
    "2.0_SelectBestModelAndRegister.py",
    "3.0_Deploy.py"
]

for script in scripts:
    full_path = os.path.join(BASE_DIR, script)
    print(f"\n=== Running {script} ===\n")

    result = subprocess.run(
        [sys.executable, full_path, "--run_name", experiment_name]
    )

    if result.returncode != 0:
        print(f"{script} failed with exit code {result.returncode}")
        break

    print(f"✔ Finished {script}")
# Out:
# === Running 0.1_read_data.py ===
# 2025-12-11 18:46:08.181 | INFO     | config:<module>:11 - PROJ_ROOT path is: /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project
# Created artifacts directory
# 'data/raw/raw_data.csv.dvc' didn't change, skipping
# M       data/raw/raw_data.csv
# M       output/artifacts/raw_data.csv
# M       output/data/raw/raw_data.csv
# 3 files modified
# Loading training data
# ✔ Finished 0.1_read_data.py
#
# === Running 0.2_data_preprocessing.py ===
# 2025-12-11 18:46:26.689 | INFO     | config:<module>:11 - PROJ_ROOT path is: /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project
# /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project/Module/0.2_data_preprocessing.py:85: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["lead_indicator"].replace("", np.nan, inplace=True)
# /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project/Module/0.2_data_preprocessing.py:86: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["lead_id"].replace("", np.nan, inplace=True)
# /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project/Module/0.2_data_preprocessing.py:87: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["customer_code"].replace("", np.nan, inplace=True)
# /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project/Module/util.py:24: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.fillna(x.mode()[0])
# Target value counter
# 0.0 :  0.5318352059925093
# 1.0 :  0.4681647940074906
# Changed lead_id to object type
# Changed lead_indicator to object type
# Changed customer_group to object type
# Changed onboarding to object type
# Changed source to object type
# Changed customer_code to object type
#
# Continuous columns:
#
# ['Unnamed: 0', 'purchases', 'time_spent', 'n_visits']
#
#  Categorical columns:
#
# [   'lead_id',
#     'lead_indicator',
#     'date_part',
#     'source',
#     'customer_group',
#     'onboarding',
#     'customer_code']
# Saved scaler in artifacts
# Data cleansed and combined.
# Rows: 2937
# Saved training golden data
# ✔ Finished 0.2_data_preprocessing.py
#
# === Running 1.0_Train.py ===
# 2025-12-11 18:46:47.686 | INFO     | config:<module>:11 - PROJ_ROOT path is: /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project
# /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:177: FutureWarning: The filesystem tracking backend (e.g., './mlruns') will be deprecated in February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://github.com/mlflow/mlflow/issues/18534 for more details and migration guidance.
#   return FileStore(store_uri, store_uri)
# Run name: 2025_December_11
# Training data length: 2937
# Changed column lead_indicator to float
# Changed column Unnamed: 0 to float
# Changed column purchases to float
# Changed column time_spent to float
# Changed column n_visits to float
# Changed column customer_group_2 to float
# Changed column customer_group_3 to float
# Changed column customer_group_4 to float
# Changed column customer_group_5 to float
# Changed column customer_group_6 to float
# Changed column customer_group_7 to float
# Changed column customer_group_8 to float
# Changed column customer_group_9 to float
# Changed column onboarding_True to float
# /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project/Module/1.0_Train.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat_vars[col] = cat_vars[col].astype("category")
# ✔ Finished 1.0_Train.py
#
# === Running 1.1_TrainXGBoost.py ===
# 2025-12-11 18:46:56.256 | INFO     | config:<module>:11 - PROJ_ROOT path is: /mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project
# Traceback (most recent call last):
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/itu-sdse-project/Module/1.1_TrainXGBoost.py", line 63, in <module>
#     model_grid.fit(X_train, y_train)
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/sklearn/base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/sklearn/model_selection/_search.py", line 1051, in fit
#     self._run_search(evaluate_candidates)
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/sklearn/model_selection/_search.py", line 1992, in _run_search
#     evaluate_candidates(
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/sklearn/model_selection/_search.py", line 1009, in evaluate_candidates
#     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#   File "/mnt/c/Users/krist/Desktop/ITU/5_semester/MLops/EXAM/ml_env/lib/python3.10/site-packages/sklearn/model_selection/_split.py", line 404, in split
#     raise ValueError(
# ValueError: Cannot have number of splits n_splits=10 greater than the number of samples: n_samples=1.
# Run name: 2025_December_11
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# 1.1_TrainXGBoost.py failed with exit code 1
